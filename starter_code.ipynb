# %%
from pybaseball import statcast
from pybaseball import statcast_batter_exitvelo_barrels
from pybaseball import batting_stats
from pybaseball import cache
from pybaseball import playerid_lookup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Fetch batting statistics for a specific season (e.g., 2023)
batting_stats_data = batting_stats(2023)

# Display all column names
print(batting_stats_data.columns)

# Set the display option to show all columns
pd.set_option('display.max_columns', None)

# Display the DataFrame
print(batting_stats_data)
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B',
#        ...
#        'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA',
#        'xSLG', 'xwOBA', 'L-WAR'],
#       dtype='object', length=320)
#       IDfg  Season               Name   Team  Age    G   AB   PA    H   1B  \
# 1    18401    2023   Ronald Acuna Jr.    ATL   25  159  643  735  217  137
# 3    13611    2023       Mookie Betts    LAD   30  152  584  693  179   99
# 5     5361    2023    Freddie Freeman    LAD   33  161  637  730  211  121
# 4    14344    2023         Matt Olson    ATL   29  162  608  720  172   88
# 0    19755    2023      Shohei Ohtani    LAA   28  135  497  599  151   73
# ..     ...     ...                ...    ...  ...  ...  ...  ...  ...  ...
# 132  15172    2023       Tim Anderson    CHW   30  123  493  524  121  100
# 125  15676    2023         Jose Abreu    HOU   36  141  540  594  128   86
# 115  17988    2023   Tyler Stephenson    CIN   26  142  465  517  113   78
# 129  10472    2023  Enrique Hernandez  - - -   31  140  465  508  110   76
# 116  10815    2023   Jurickson Profar  - - -   30  125  459  521  111   73
#
#      2B  3B  HR    R  RBI   BB  IBB   SO  HBP  SF  SH  GDP  SB  CS    AVG  \
# 1    35   4  41  149  106   80    3   84    9   3   0   15  73  14  0.337
# 3    40   1  39  126  107   96    3  107    8   5   0    5  14   3  0.307
# 5    59   2  29  131  102   72   12  121   16   5   0   14  23   1  0.331
# 4    27   3  54  127  139  104    8  167    4   4   0   13   1   0  0.283
# 0    26   8  44  102   95   91   21  143    3   3   0    9  20   6  0.304
# ..   ..  ..  ..  ...  ...  ...  ...  ...  ...  ..  ..  ...  ..  ..    ...
# 132  18   2   1   52   25   26    0  122    3   2   0   15  13   2  0.245
# 125  23   1  18   62   90   42    1  130    6   6   0   16   0   1  0.237
# 115  20   2  13   59   56   47    2  135    4   1   0   16   0   1  0.243
# 129  23   0  11   57   61   34    1   97    3   6   0   17   4   1  0.237
# 116  27   2   9   55   46   50    0   90    6   5   0   11   1   0  0.242
#
#       GB   FB   LD  IFFB  Pitches  Balls  Strikes  IFH  BU  BUH    BB%     K%  \
# 1    278  171  113     8     2789   1120     1669   23   0    0  0.109  0.114
# 3    134  234  114    21     2715   1125     1590    9   0    0  0.139  0.154
# 5    184  193  144     7     2755   1037     1718    6   0    0  0.099  0.166
# 4    172  194   79     6     3096   1243     1853    5   0    0  0.144  0.232
# 0    151  141   65     8     2329    916     1413   11   0    0  0.152  0.239
# ..   ...  ...  ...   ...      ...    ...      ...  ...  ..  ...    ...    ...
# 132  228   63   82     2     1947    636     1311   13   0    0  0.050  0.233
# 125  187  151   78    12     2403    788     1615   13   0    0  0.071  0.219
# 115  161   95   75     4     2051    787     1264   11   0    0  0.091  0.261
# 129  140  163   71    19     1968    702     1266    5   0    0  0.067  0.191
# 116  150  139   85    20     2109    795     1314    3   0    0  0.096  0.173
#
#      BB/K    OBP    SLG    OPS    ISO  BABIP   GB/FB    LD%    GB%    FB%  \
# 1    0.95  0.416  0.596  1.012  0.258  0.338  0.0163  0.201  0.495  0.304
# 3    0.90  0.408  0.579  0.987  0.272  0.316  0.0057  0.237  0.278  0.485
# 5    0.60  0.410  0.567  0.976  0.235  0.370  0.0095  0.276  0.353  0.370
# 4    0.62  0.389  0.604  0.993  0.321  0.302  0.0089  0.178  0.387  0.436
# 0    0.64  0.412  0.654  1.066  0.350  0.342  0.0107  0.182  0.423  0.395
# ..    ...    ...    ...    ...    ...    ...     ...    ...    ...    ...
# 132  0.21  0.286  0.296  0.582  0.051  0.323  0.0362  0.220  0.611  0.169
# 125  0.32  0.296  0.383  0.680  0.146  0.276  0.0124  0.188  0.450  0.363
# 115  0.35  0.317  0.378  0.696  0.135  0.314  0.0169  0.227  0.486  0.287
# 129  0.35  0.289  0.357  0.646  0.120  0.273  0.0086  0.190  0.374  0.436
# 116  0.56  0.321  0.368  0.689  0.126  0.279  0.0108  0.227  0.401  0.372
#
#      IFFB%  HR/FB   IFH%  BUH%   wOBA  wRAA  wRC   Bat   Fld   Rep   Pos  \
# 1    0.047  0.240  0.083   0.0  0.428  66.7  156  64.1  -6.3  22.8  -7.2
# 3    0.090  0.167  0.067   0.0  0.416  56.5  141  57.3   0.7  21.5  -2.3
# 5    0.036  0.150  0.033   0.0  0.411  55.9  145  56.8   4.3  22.7 -11.8
# 4    0.031  0.278  0.029   0.0  0.413  56.4  144  53.9  -0.4  22.4 -12.2
# 0    0.057  0.312  0.073   0.0  0.433  57.3  130  57.1   NaN  18.6 -14.5
# ..     ...    ...    ...   ...    ...   ...  ...   ...   ...   ...   ...
# 132  0.032  0.016  0.057   0.0  0.260 -25.6   38 -25.1  -1.7  16.3   5.2
# 125  0.079  0.119  0.070   0.0  0.295 -11.4   61  -9.6  -1.9  18.4 -10.9
# 115  0.042  0.137  0.068   0.0  0.305  -5.7   57  -9.9 -10.3  16.1   1.0
# 129  0.117  0.067  0.036   0.0  0.282 -15.4   46 -16.9 -12.8  15.8   2.9
# 116  0.144  0.065  0.020   0.0  0.304  -6.0   57 -15.4 -12.8  16.2  -6.3
#
#       RAR  WAR      Dol  Spd  wRC+   WPA   -WPA   +WPA   RE24   REW   pLI  \
# 1    83.1  8.3    $66.3  7.3   170  6.87 -10.14  17.00  73.57  7.21  0.92
# 3    82.8  8.3    $66.1  4.7   167  5.21 -10.04  15.25  65.20  6.57  0.97
# 5    79.2  7.9    $63.2  6.0   163  4.49 -10.69  15.18  71.10  7.06  0.96
# 4    67.2  6.7    $53.6  3.1   160  4.45 -10.28  14.72  66.18  6.52  0.90
# 0    66.4  6.6    $53.0  6.6   180  4.13  -9.35  13.48  61.13  6.08  1.01
# ..    ...  ...      ...  ...   ...   ...    ...    ...    ...   ...   ...
# 132  -4.9 -0.5   ($3.9)  5.2    60 -4.06 -10.17   6.12 -32.92 -3.26  0.96
# 125  -6.4 -0.6   ($5.1)  2.0    86 -1.16 -11.33  10.18  -1.56 -0.22  1.03
# 115  -7.2 -0.7   ($5.7)  2.7    85 -2.40 -10.64   8.24 -18.32 -1.80  1.03
# 129 -12.7 -1.3  ($10.1)  3.3    72 -1.01  -8.60   7.59 -18.21 -1.73  0.92
# 116 -19.7 -2.0  ($15.7)  2.9    76 -1.08  -9.31   8.23 -12.12 -1.14  0.97
#
#      phLI  PH  WPA/LI  Clutch  FB% (Pitch)   FBv    SL%   SLv    CT%   CTv  \
# 1     NaN   0    6.30    1.16        0.525  93.9  0.234  85.1  0.059  89.3
# 3    1.15   1    6.11   -0.72        0.517  94.0  0.235  84.9  0.078  88.9
# 5     NaN   0    6.18   -1.50        0.464  94.0  0.213  84.7  0.079  89.4
# 4     NaN   0    5.54   -0.60        0.496  94.1  0.192  84.5  0.084  89.6
# 0     NaN   0    6.16   -2.08        0.403  94.6  0.231  85.1  0.093  89.9
# ..    ...  ..     ...     ...          ...   ...    ...   ...    ...   ...
# 132  3.74   2   -3.02   -1.19        0.490  93.4  0.277  84.2  0.060  88.9
# 125   NaN   0   -1.15    0.02        0.519  94.3  0.251  84.5  0.060  88.8
# 115  1.98  12   -1.30   -1.04        0.515  93.9  0.221  84.6  0.078  88.5
# 129  1.49   9   -1.52    0.43        0.451  93.3  0.259  84.7  0.090  88.5
# 116  2.61  10   -1.37    0.26        0.480  93.9  0.178  84.7  0.096  89.6
#
#        CB%   CBv    CH%   CHv    SF%   SFv    KN%   KNv    XX%  PO%   wFB  \
# 1    0.072  80.2  0.088  85.5  0.022  85.5    NaN   NaN  0.007  NaN  31.2
# 3    0.069  79.8  0.083  86.0  0.018  88.0    NaN   NaN  0.006  NaN  34.6
# 5    0.104  79.7  0.121  86.3  0.021  87.9    NaN   NaN  0.015  NaN  26.4
# 4    0.079  80.6  0.126  86.3  0.024  86.4    NaN   NaN  0.012  NaN  29.4
# 0    0.076  80.0  0.152  86.6  0.045  86.8    NaN   NaN  0.035  NaN  28.0
# ..     ...   ...    ...   ...    ...   ...    ...   ...    ...  ...   ...
# 132  0.065  79.4  0.090  85.0  0.018  85.1    NaN   NaN  0.003  NaN  -0.6
# 125  0.087  80.1  0.068  84.7  0.014  86.3  0.001  74.0  0.003  NaN  -8.1
# 115  0.075  78.5  0.095  85.5  0.016  86.1    NaN   NaN  0.003  NaN  -0.6
# 129  0.074  80.7  0.105  84.4  0.021  86.6    NaN   NaN  0.004  NaN  -9.8
# 116  0.082  80.2  0.145  86.0  0.019  86.3    NaN   NaN  0.002  NaN   4.7
#
#       wSL  wCT   wCB   wCH  wSF  wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  \
# 1    18.3  4.6  10.5   2.4  1.8  NaN   2.14   2.80   2.80   5.25   0.96
# 3    10.0  2.9   7.5   4.4  0.0  NaN   2.47   1.57   1.39   4.02   1.93
# 5     8.4  4.1   4.7  15.5 -1.0  NaN   2.07   1.43   1.90   1.63   4.66
# 4     7.8  3.4  -0.7  11.0  3.2  NaN   1.92   1.31   1.30  -0.27   2.83
# 0     6.6  7.0   5.5   6.5  1.3  NaN   3.00   1.23   3.22   3.10   1.85
# ..    ...  ...   ...   ...  ...  ...    ...    ...    ...    ...    ...
# 132 -18.3 -2.7  -1.4  -5.0 -1.2  NaN  -0.06  -3.40  -2.33  -1.14  -2.84
# 125  -6.3  3.8   1.4  -2.1  0.3  0.1  -0.65  -1.05   2.68   0.66  -1.31
# 115   0.4 -3.9   1.3  -2.7  0.2  NaN  -0.06   0.08  -2.46   0.85  -1.38
# 129  -5.2 -6.2   3.0  -0.1 -2.4  NaN  -1.11  -1.03  -3.51   2.08  -0.04
# 116  -4.9 -3.6   2.2  -3.6 -0.9  NaN   0.47  -1.31  -1.81   1.29  -1.19
#
#      wSF/C  wKN/C  O-Swing%  Z-Swing%  Swing%  O-Contact%  Z-Contact%  \
# 1     2.97    NaN     0.268     0.728   0.462       0.738       0.878
# 3     0.04    NaN     0.200     0.630   0.381       0.643       0.939
# 5    -1.79    NaN     0.301     0.792   0.510       0.688       0.880
# 4     4.38    NaN     0.295     0.735   0.469       0.695       0.777
# 0     1.22    NaN     0.333     0.707   0.480       0.565       0.814
# ..     ...    ...       ...       ...     ...         ...         ...
# 132  -3.46    NaN     0.386     0.726   0.535       0.641       0.856
# 125   0.93   4.12     0.389     0.663   0.502       0.642       0.856
# 115   0.48    NaN     0.275     0.633   0.426       0.564       0.850
# 129  -5.71    NaN     0.307     0.686   0.467       0.632       0.872
# 116  -2.27    NaN     0.277     0.724   0.471       0.664       0.897
#
#      Contact%  Zone%  F-Strike%  SwStr%  BsR  FA% (sc)  FT% (sc)  FC% (sc)  \
# 1       0.831  0.422      0.589   0.078  7.6     0.308       NaN     0.058
# 3       0.849  0.421      0.595   0.058  3.5     0.316       NaN     0.090
# 5       0.815  0.426      0.614   0.094  5.1     0.309       NaN     0.090
# 4       0.746  0.395      0.556   0.119  1.5     0.365       NaN     0.081
# 0       0.709  0.393      0.571   0.139  3.4     0.290       NaN     0.101
# ..        ...    ...        ...     ...  ...       ...       ...       ...
# 132     0.769  0.438      0.658   0.123 -1.0     0.300       NaN     0.062
# 125     0.758  0.411      0.593   0.121 -4.1     0.341       NaN     0.060
# 115     0.743  0.421      0.634   0.109 -5.7     0.289       NaN     0.079
# 129     0.781  0.422      0.614   0.102 -3.1     0.295       NaN     0.095
# 116     0.819  0.434      0.633   0.085 -3.0     0.375       NaN     0.094
#
#      FS% (sc)  FO% (sc)  SI% (sc)  SL% (sc)  CU% (sc)  KC% (sc)  EP% (sc)  \
# 1       0.021     0.001     0.214     0.235     0.053     0.019     0.002
# 3       0.016     0.002     0.200     0.223     0.055     0.015       NaN
# 5       0.021     0.001     0.154     0.199     0.087     0.020       NaN
# 4       0.021     0.002     0.131     0.191     0.066     0.019       NaN
# 0       0.043     0.001     0.108     0.220     0.070     0.014       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 132     0.014       NaN     0.186     0.275     0.057     0.008     0.002
# 125     0.011       NaN     0.178     0.251     0.065     0.022       NaN
# 115     0.021     0.001     0.228     0.216     0.062     0.016     0.001
# 129     0.015       NaN     0.147     0.251     0.074     0.008     0.005
# 116     0.018     0.003     0.102     0.184     0.066     0.016       NaN
#
#      CH% (sc)  SC% (sc)  KN% (sc)  UN% (sc)  vFA (sc)  vFT (sc)  vFC (sc)  \
# 1       0.087     0.001       NaN       NaN      94.3       NaN      89.3
# 3       0.084     0.000       NaN       NaN      94.3       NaN      89.0
# 5       0.118       NaN       NaN       NaN      94.3       NaN      89.5
# 4       0.125     0.000       NaN       NaN      94.3       NaN      89.6
# 0       0.152       NaN       NaN       NaN      94.8       NaN      90.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 132     0.096       NaN       NaN       NaN      94.0       NaN      88.8
# 125     0.070       NaN     0.001       NaN      94.4       NaN      89.1
# 115     0.089     0.001       NaN       NaN      94.1       NaN      88.8
# 129     0.111       NaN       NaN       NaN      93.8       NaN      88.7
# 116     0.142     0.001       NaN       NaN      93.9       NaN      90.0
#
#      vFS (sc)  vFO (sc)  vSI (sc)  vSL (sc)  vCU (sc)  vKC (sc)  vEP (sc)  \
# 1        85.5      81.9      93.7      85.0      79.1      82.5      50.8
# 3        88.8      83.2      93.4      84.7      79.6      80.9       NaN
# 5        87.8      84.1      93.2      84.5      79.4      80.6       NaN
# 4        86.5      84.7      93.3      84.8      79.7      82.8       NaN
# 0        86.6      83.3      93.9      85.1      79.9      80.9       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 132      85.6       NaN      93.1      84.1      79.1      82.3      43.5
# 125      86.7       NaN      93.8      84.3      79.7      81.3       NaN
# 115      87.0      83.2      93.6      84.4      78.0      80.4      51.8
# 129      86.5       NaN      93.5      84.7      80.6      82.2      45.5
# 116      87.4      84.2      93.0      84.8      79.5      81.0       NaN
#
#      vCH (sc)  vSC (sc)  vKN (sc)  FA-X (sc)  FT-X (sc)  FC-X (sc)  FS-X (sc)  \
# 1        85.5      81.3       NaN       -2.5        NaN        0.6       -5.0
# 3        86.0      79.9       NaN       -1.6        NaN        0.4       -6.8
# 5        86.2       NaN       NaN       -2.1        NaN        0.4       -6.9
# 4        86.1      80.7       NaN       -2.6        NaN        0.3       -5.7
# 0        86.6       NaN       NaN       -2.0        NaN        0.3       -6.8
# ..        ...       ...       ...        ...        ...        ...        ...
# 132      85.0       NaN       NaN       -1.6        NaN        0.8       -7.6
# 125      84.6       NaN      73.8       -1.0        NaN        0.7       -7.4
# 115      85.2      82.0       NaN       -2.1        NaN        0.3       -7.1
# 129      84.5       NaN       NaN       -0.9        NaN        0.5       -7.9
# 116      85.9      81.4       NaN       -1.9        NaN        0.0       -4.6
#
#      FO-X (sc)  SI-X (sc)  SL-X (sc)  CU-X (sc)  KC-X (sc)  EP-X (sc)  \
# 1         -6.1       -6.3        2.1        2.0        3.0       -3.1
# 3         -5.7       -5.0        2.2        1.6        3.0        NaN
# 5         -6.7       -2.9        0.2        1.3        2.5        NaN
# 4         -3.9       -1.9        1.5        2.2        2.6        NaN
# 0         -4.9       -0.4        0.8        3.2        3.0        NaN
# ..         ...        ...        ...        ...        ...        ...
# 132        NaN       -6.3        2.6        0.4        2.2        1.5
# 125        NaN       -5.3        1.8        1.2        2.1        NaN
# 115       -2.4       -5.4        1.9        1.0        2.2       -2.6
# 129        NaN       -4.3        2.1        0.9        3.6        2.5
# 116       -3.7       -2.8        1.4        1.6        2.7        NaN
#
#      CH-X (sc)  SC-X (sc)  KN-X (sc)  FA-Z (sc)  FT-Z (sc)  FC-Z (sc)  \
# 1         -2.0       -7.0        NaN        9.0        NaN        4.6
# 3         -0.7       -6.2        NaN        9.1        NaN        4.3
# 5         -6.2        NaN        NaN        8.9        NaN        4.4
# 4         -5.9       -6.0        NaN        8.8        NaN        4.6
# 0         -7.4        NaN        NaN        9.3        NaN        4.1
# ..         ...        ...        ...        ...        ...        ...
# 132       -0.8        NaN        NaN        9.2        NaN        4.2
# 125        2.4        NaN       -2.5        9.5        NaN        3.8
# 115       -1.1       -5.6        NaN        9.3        NaN        4.6
# 129        2.3        NaN        NaN        9.3        NaN        4.6
# 116       -3.4       -4.5        NaN        8.3        NaN        4.4
#
#      FS-Z (sc)  FO-Z (sc)  SI-Z (sc)  SL-Z (sc)  CU-Z (sc)  KC-Z (sc)  \
# 1          1.9        0.4        4.8        1.2       -5.4       -5.1
# 3          2.4        2.9        4.7        1.3       -4.6       -4.4
# 5          1.8        1.6        4.2        1.3       -4.7       -3.2
# 4          1.8       -0.2        4.5        1.1       -5.1       -4.8
# 0          2.0        0.0        4.9        1.2       -5.6       -3.7
# ..         ...        ...        ...        ...        ...        ...
# 132        2.3        NaN        5.2        0.7       -5.7       -6.2
# 125        2.8        NaN        5.0        1.1       -5.3       -5.0
# 115        0.6        6.7        5.0        1.2       -5.3       -2.6
# 129        1.5        NaN        4.8        1.3       -4.2       -4.7
# 116        2.3        1.2        4.8        1.2       -5.1       -5.4
#
#      EP-Z (sc)  CH-Z (sc)  SC-Z (sc)  KN-Z (sc)  wFA (sc)  wFT (sc)  wFC (sc)  \
# 1          6.4        3.4       -2.6        NaN      15.9       NaN       4.2
# 3          NaN        3.4       -0.3        NaN      19.3       NaN       0.7
# 5          NaN        2.9        NaN        NaN      14.2       NaN       2.3
# 4          NaN        3.2       -2.0        NaN      23.2       NaN       1.1
# 0          NaN        3.8        NaN        NaN      22.3       NaN       6.2
# ..         ...        ...        ...        ...       ...       ...       ...
# 132        9.1        3.4        NaN        NaN      -3.0       NaN      -2.1
# 125        NaN        4.5        NaN       -5.8      -3.0       NaN       3.3
# 115        6.1        3.4        0.8        NaN       6.5       NaN      -5.6
# 129        8.1        3.6        NaN        NaN       0.3       NaN      -5.4
# 116        NaN        2.9        1.1        NaN       1.8       NaN      -4.8
#
#      wFS (sc)  wFO (sc)  wSI (sc)  wSL (sc)  wCU (sc)  wKC (sc)  wEP (sc)  \
# 1         1.4       0.0      13.2      14.9      10.9      -0.2       0.9
# 3         1.1       0.0      15.8      12.4       4.3       2.5       NaN
# 5        -0.4       0.4       9.6      10.3       3.6       0.5       NaN
# 4         2.4      -0.2       7.2      10.3       1.4      -1.8       NaN
# 0         1.7       0.2       6.0       7.7       4.3       0.0       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 132      -2.1       NaN       1.5     -19.1      -1.9       0.1       0.5
# 125       1.0       NaN      -7.3      -4.2       0.6      -0.5       NaN
# 115      -1.7       0.5      -8.0       1.6       1.4      -0.2      -0.3
# 129      -1.4       NaN      -8.8      -5.8       1.6      -0.1      -1.1
# 116      -0.4      -0.2       2.7      -5.5       0.3       1.8       NaN
#
#      wCH (sc)  wSC (sc)  wKN (sc)  wFA/C (sc)  wFT/C (sc)  wFC/C (sc)  \
# 1         2.9       0.1       NaN        1.86         NaN        2.62
# 3         2.8      -0.2       NaN        2.25         NaN        0.28
# 5        13.8       NaN       NaN        1.67         NaN        0.94
# 4         9.4       0.3       NaN        2.06         NaN        0.44
# 0         5.7       NaN       NaN        3.34         NaN        2.66
# ..        ...       ...       ...         ...         ...         ...
# 132      -4.3       NaN       NaN       -0.51         NaN       -1.73
# 125      -2.6       NaN       0.1       -0.37         NaN        2.27
# 115      -1.7       0.1       NaN        1.10         NaN       -3.47
# 129      -1.1       NaN       NaN        0.05         NaN       -2.88
# 116      -3.6      -0.2       NaN        0.23         NaN       -2.42
#
#      wFS/C (sc)  wFO/C (sc)  wSI/C (sc)  wSL/C (sc)  wCU/C (sc)  wKC/C (sc)  \
# 1          2.34       -1.14        2.23        2.29        7.40       -0.36
# 3          2.57       -0.99        2.92        2.06        2.90        6.16
# 5         -0.71       18.13        2.27        1.89        1.49        0.88
# 4          3.81       -3.01        1.78        1.75        0.69       -3.20
# 0          1.69        8.00        2.40        1.51        2.63       -0.10
# ..          ...         ...         ...         ...         ...         ...
# 132       -7.63         NaN        0.43       -3.58       -1.70        0.78
# 125        3.73         NaN       -1.70       -0.70        0.37       -0.97
# 115       -4.03       51.37       -1.72        0.35        1.13       -0.54
# 129       -4.60         NaN       -3.04       -1.18        1.13       -0.59
# 116       -0.97       -2.66        1.27       -1.43        0.22        5.30
#
#      wEP/C (sc)  wCH/C (sc)  wSC/C (sc)  wKN/C (sc)  O-Swing% (sc)  \
# 1         18.17        1.21        4.32         NaN          0.227
# 3           NaN        1.24      -16.65         NaN          0.179
# 5           NaN        4.22         NaN         NaN          0.270
# 4           NaN        2.44       27.63         NaN          0.259
# 0           NaN        1.63         NaN         NaN          0.300
# ..          ...         ...         ...         ...            ...
# 132       11.84       -2.29         NaN         NaN          0.348
# 125         NaN       -1.52         NaN        4.12          0.363
# 115      -33.62       -0.92        8.63         NaN          0.235
# 129      -11.91       -0.49         NaN         NaN          0.281
# 116         NaN       -1.22      -22.48         NaN          0.241
#
#      Z-Swing% (sc)  Swing% (sc)  O-Contact% (sc)  Z-Contact% (sc)  \
# 1            0.692        0.462            0.676            0.879
# 3            0.584        0.381            0.566            0.937
# 5            0.755        0.510            0.662            0.870
# 4            0.705        0.468            0.641            0.791
# 0            0.692        0.482            0.504            0.812
# ..             ...          ...              ...              ...
# 132          0.702        0.535            0.566            0.857
# 125          0.639        0.501            0.579            0.854
# 115          0.607        0.425            0.470            0.841
# 129          0.646        0.467            0.563            0.870
# 116          0.683        0.471            0.597            0.890
#
#      Contact% (sc)  Zone% (sc)  Pace   Def  wSB  UBR  Age Rng   Off   Lg  \
# 1            0.830       0.506  18.4 -13.6  7.0  2.2  25 - 25  71.7  2.2
# 3            0.849       0.498  18.0  -1.6  0.0  2.3  30 - 30  60.8  2.1
# 5            0.814       0.495  18.7  -7.5  2.7  1.4  33 - 33  61.8  2.2
# 4            0.746       0.468  18.9 -12.6 -1.2  2.3  29 - 29  55.4  2.2
# 0            0.710       0.465  18.8 -14.5  0.3  1.7  28 - 28  60.6  1.8
# ..             ...         ...   ...   ...  ...  ...      ...   ...  ...
# 132          0.767       0.527  18.0   3.4  0.8  0.7  30 - 30 -26.1  1.5
# 125          0.755       0.501  18.9 -12.9 -1.4 -1.3  36 - 36 -13.8  1.7
# 115          0.742       0.513  18.4  -9.2 -1.4 -1.9  26 - 26 -15.6  1.6
# 129          0.780       0.511  19.1 -10.0 -0.5 -0.2  31 - 31 -20.0  1.5
# 116          0.818       0.521  18.1 -19.1 -0.8 -1.3  30 - 30 -18.4  1.6
#
#      wGDP  Pull%  Cent%  Oppo%  Soft%   Med%  Hard%   TTO%  CH% (pi)  \
# 1    -1.6  0.397  0.356  0.247  0.101  0.438  0.461  0.279     0.088
# 3     1.2  0.463  0.355  0.183  0.100  0.490  0.411  0.349     0.082
# 5     1.0  0.365  0.357  0.278  0.106  0.526  0.369  0.304     0.116
# 4     0.4  0.382  0.373  0.245  0.112  0.461  0.427  0.451     0.123
# 0     1.4  0.389  0.361  0.249  0.098  0.473  0.429  0.464     0.150
# ..    ...    ...    ...    ...    ...    ...    ...    ...       ...
# 132  -2.5  0.335  0.386  0.279  0.129  0.590  0.282  0.284     0.094
# 125  -1.4  0.339  0.404  0.257  0.188  0.526  0.286  0.320     0.071
# 115  -2.4  0.399  0.329  0.272  0.112  0.550  0.338  0.377     0.089
# 129  -2.4  0.366  0.374  0.259  0.174  0.562  0.265  0.280     0.115
# 116  -0.9  0.447  0.337  0.217  0.195  0.473  0.332  0.286     0.140
#
#      CS% (pi)  CU% (pi)  FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  SB% (pi)  \
# 1         NaN     0.068     0.303     0.064     0.023       NaN     0.001
# 3         NaN     0.061     0.317     0.084     0.018       NaN     0.000
# 5         NaN     0.097     0.304     0.081     0.024       NaN       NaN
# 4         NaN     0.079     0.354     0.087     0.027       NaN     0.000
# 0       0.000     0.076     0.287     0.095     0.047       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 132     0.001     0.057     0.295     0.059     0.013       NaN       NaN
# 125       NaN     0.078     0.341     0.060     0.010     0.001       NaN
# 115       NaN     0.069     0.279     0.081     0.022       NaN     0.001
# 129       NaN     0.068     0.295     0.094     0.016       NaN       NaN
# 116     0.001     0.077     0.367     0.101     0.025       NaN     0.001
#
#      SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  vFA (pi)  \
# 1       0.215     0.238       NaN      85.2       NaN      79.6      94.4
# 3       0.198     0.239       NaN      86.1       NaN      79.6      94.3
# 5       0.159     0.219     0.000      86.3       NaN      79.6      94.3
# 4       0.130     0.200       NaN      86.3       NaN      80.4      94.4
# 0       0.109     0.234     0.001      86.6      77.2      80.1      94.7
# ..        ...       ...       ...       ...       ...       ...       ...
# 132     0.192     0.289       NaN      85.1      75.6      79.3      93.8
# 125     0.173     0.265       NaN      84.7       NaN      79.8      94.5
# 115     0.231     0.228       NaN      85.1       NaN      78.4      94.4
# 129     0.144     0.267     0.001      83.1       NaN      80.8      94.1
# 116     0.103     0.186     0.001      86.0      77.3      80.1      94.1
#
#      vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  vXX (pi)  \
# 1        89.5      85.5       NaN      81.9      93.9      85.2       NaN
# 3        89.0      86.9       NaN      80.1      93.6      84.9       NaN
# 5        89.8      86.7       NaN       NaN      93.5      84.5      83.1
# 4        90.1      86.4       NaN      81.4      93.6      84.8       NaN
# 0        90.5      86.4       NaN       NaN      94.1      84.8      86.1
# ..        ...       ...       ...       ...       ...       ...       ...
# 132      89.1      85.4       NaN       NaN      93.3      84.3       NaN
# 125      89.3      86.1      74.1       NaN      93.9      84.5       NaN
# 115      89.2      87.1       NaN      81.9      93.8      84.6       NaN
# 129      89.0      86.4       NaN       NaN      93.7      84.6      85.1
# 116      90.4      86.9       NaN      81.7      93.5      84.9      53.5
#
#      CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  \
# 1         -1.8        NaN        2.8       -2.1        0.7       -4.9
# 3         -0.4        NaN        2.6       -1.3        0.7       -5.7
# 5         -6.0        NaN        2.1       -1.7        0.6       -5.9
# 4         -5.8        NaN        3.0       -2.4        0.8       -4.7
# 0         -7.3        5.7        3.3       -1.8        1.1       -6.4
# ..         ...        ...        ...        ...        ...        ...
# 132       -0.5        4.5        0.8       -1.4        0.8       -7.1
# 125        2.3        NaN        1.0       -1.0        0.8       -7.7
# 115       -1.1        NaN        1.1       -1.9        0.6       -6.4
# 129        2.1        NaN        1.6       -0.8        0.8       -6.7
# 116       -3.4        4.8        1.9       -1.7        0.1       -4.6
#
#      KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  \
# 1          NaN       -6.6       -6.2        2.6        NaN        2.2
# 3          NaN       -5.3       -4.8        2.8        NaN        2.2
# 5          NaN        NaN       -2.9        0.2        0.0        1.8
# 4          NaN       -5.4       -2.1        1.5        NaN        1.9
# 0          NaN        NaN       -0.8        0.8        0.0        2.4
# ..         ...        ...        ...        ...        ...        ...
# 132        NaN        NaN       -5.9        3.3        NaN        2.0
# 125       -2.0        NaN       -5.2        2.3        NaN        3.0
# 115        NaN       -5.4       -5.1        2.3        NaN        2.1
# 129        NaN        NaN       -3.9        2.4        0.0        2.4
# 116        NaN       -4.6       -3.3        1.5        0.0        2.0
#
#      CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  \
# 1          NaN       -7.1        8.1        3.7        0.6        NaN
# 3          NaN       -6.6        8.2        3.5        1.0        NaN
# 5          NaN       -6.3        8.0        3.9        0.7        NaN
# 4          NaN       -6.9        8.0        4.1        0.6        NaN
# 0        -10.4       -7.2        8.3        3.6        0.7        NaN
# ..         ...        ...        ...        ...        ...        ...
# 132      -10.6       -7.6        8.3        3.3        1.0        NaN
# 125        NaN       -7.3        8.4        3.1        1.2       -7.2
# 115        NaN       -6.4        8.4        3.8       -0.2        NaN
# 129        NaN       -6.4        8.3        3.6        0.2        NaN
# 116       -8.2       -6.4        7.7        3.8        1.2        NaN
#
#      SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  \
# 1         -4.1        3.8       -0.1        NaN       3.2       NaN       8.2
# 3         -2.3        3.5        0.1        NaN       1.3       NaN       6.9
# 5          NaN        3.3        0.1        0.0      15.3       NaN       4.5
# 4         -3.5        3.6       -0.1        NaN      10.4       NaN      -1.7
# 0          NaN        3.8       -0.4        0.0       5.3       0.0       4.8
# ..         ...        ...        ...        ...       ...       ...       ...
# 132        NaN        4.1       -0.6        NaN      -4.3       0.0      -1.5
# 125        NaN        3.6       -0.5        NaN      -2.6       NaN      -0.3
# 115       -0.7        3.9       -0.1        NaN      -2.5       NaN       3.5
# 129        NaN        3.6        0.0        0.0      -2.4       NaN       2.3
# 116        0.9        4.0        0.3        0.0      -4.7      -0.2       2.0
#
#      wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  \
# 1        14.9       4.6       1.7       NaN       0.1      13.5      17.2
# 3        20.1       1.4       2.0       NaN      -0.2      16.6      10.9
# 5        13.7       2.7      -0.6       NaN       NaN       9.6       9.5
# 4        23.2       4.3       2.2       NaN       0.3       6.6       7.9
# 0        19.9       7.5       2.0       NaN       NaN       5.7       7.4
# ..        ...       ...       ...       ...       ...       ...       ...
# 132      -2.7      -2.0      -2.0       NaN       NaN       1.5     -19.1
# 125      -2.0       3.6       1.0       0.1       NaN      -7.6      -4.9
# 115       4.2      -2.1      -0.7       NaN       0.1      -8.8      -1.2
# 129       1.6      -5.9      -1.4       NaN       NaN      -8.8      -6.7
# 116       1.3      -5.2       0.3       NaN      -0.2       4.1      -6.0
#
#      wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  \
# 1         NaN        1.32         NaN        4.31        1.78        2.58
# 3         NaN        0.60         NaN        4.23        2.37        0.63
# 5         0.0        4.82         NaN        1.71        1.66        1.19
# 4         NaN        2.76         NaN       -0.72        2.13        1.60
# 0         0.0        1.55        3.64        2.77        3.04        3.42
# ..        ...         ...         ...         ...         ...         ...
# 132       NaN       -2.33       -4.16       -1.38       -0.47       -1.76
# 125       NaN       -1.54         NaN       -0.18       -0.24        2.47
# 115       NaN       -1.36         NaN        2.46        0.74       -1.25
# 129      -0.3       -1.07         NaN        1.75        0.28       -3.21
# 116       0.0       -1.59      -10.92        1.25        0.17       -2.46
#
#      wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  \
# 1          2.74         NaN        4.32        2.28        2.62         NaN
# 3          4.11         NaN      -16.65        3.14        1.71         NaN
# 5         -0.94         NaN         NaN        2.21        1.59        4.60
# 4          2.69         NaN       27.63        1.66        1.29         NaN
# 0          1.82         NaN         NaN        2.30        1.39       -0.73
# ..          ...         ...         ...         ...         ...         ...
# 132       -7.76         NaN         NaN        0.40       -3.41         NaN
# 125        4.07        4.12         NaN       -1.84       -0.78         NaN
# 115       -1.56         NaN        8.63       -1.85       -0.25         NaN
# 129       -4.40         NaN         NaN       -3.12       -1.28      -26.12
# 116        0.58         NaN      -22.48        1.92       -1.53        3.64
#
#      O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 1            0.224          0.689        0.462            0.670
# 3            0.177          0.583        0.379            0.580
# 5            0.269          0.749        0.509            0.658
# 4            0.262          0.700        0.466            0.654
# 0            0.300          0.687        0.483            0.499
# ..             ...            ...          ...              ...
# 132          0.355          0.695        0.534            0.572
# 125          0.365          0.635        0.501            0.573
# 115          0.231          0.611        0.425            0.487
# 129          0.272          0.653        0.466            0.573
# 116          0.245          0.685        0.472            0.619
#
#      Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)   FRM  AVG+  BB%+  \
# 1              0.881          0.831       0.511       18.4   NaN   135   124
# 3              0.935          0.852       0.499       18.0   NaN   123   157
# 5              0.870          0.814       0.500       18.7   NaN   132   112
# 4              0.788          0.748       0.467       18.9   NaN   113   164
# 0              0.815          0.711       0.473       18.8   NaN   123   181
# ..               ...            ...         ...        ...   ...   ...   ...
# 132            0.858          0.767       0.525       18.0   NaN    99    59
# 125            0.857          0.755       0.505       18.9   NaN    96    84
# 115            0.835          0.743       0.510       18.4 -10.6    97   103
# 129            0.863          0.779       0.508       19.1   NaN    95    79
# 116            0.884          0.818       0.516       18.1   NaN    97   109
#
#      K%+  OBP+  SLG+  ISO+  BABIP+  LD+%  GB%+  FB%+  HR/FB%+  Pull%+  Cent%+  \
# 1     51   129   143   155     114  1.00   115    82      186      97     103
# 3     69   126   139   164     106  1.18    65   131      129     113     102
# 5     74   127   136   141     125  1.38    82   100      117      89     103
# 4    104   120   145   193     102  0.88    90   118      216      93     108
# 0    103   130   159   212     115  0.91   100   104      248      95     105
# ..   ...   ...   ...   ...     ...   ...   ...   ...      ...     ...     ...
# 132  101    90    72    31     109  1.10   145    44       13      81     112
# 125   95    93    93    89      93  0.94   107    96       95      82     117
# 115  117    98    91    81     106  1.13   113    78      106      97      95
# 129   83    91    86    73      92  0.95    88   116       53      89     108
# 116   77    99    88    76      94  1.13    93   100       50     109      97
#
#      Oppo%+  Soft%+  Med%+  Hard%+    EV    LA  Barrels  Barrel%  maxEV  \
# 1       102      65     85     140  94.7   7.4       86    0.153  121.2
# 3        75      64     95     125  92.4  20.6       60    0.125  110.1
# 5       114      68    102     112  90.0  15.2       58    0.111  110.6
# 4       101      72     89     130  93.7  16.1       73    0.164  118.6
# 0       103      63     91     132  94.4  13.2       70    0.193  118.6
# ..      ...     ...    ...     ...   ...   ...      ...      ...    ...
# 132     115      83    113      87  87.8   2.0       11    0.030  109.6
# 125     106     121    101      88  89.0  10.8       36    0.087  113.3
# 115     112      72    106     103  89.4   8.9       25    0.076  111.1
# 129     107     112    108      81  87.8  17.0       17    0.046  109.2
# 116      89     125     92     101  86.5  14.8       15    0.040  108.8
#
#      HardHit  HardHit%  Events  CStr%   CSW%    xBA   xSLG  xwOBA  L-WAR
# 1        309     0.550     562  0.137  0.214  0.356  0.660  0.463    8.6
# 3        232     0.481     482  0.205  0.262  0.295  0.565  0.411    8.6
# 5        218     0.418     521  0.114  0.208  0.320  0.564  0.409    7.6
# 4        245     0.551     445  0.131  0.249  0.263  0.561  0.394    6.8
# 0        193     0.533     362  0.125  0.265  0.294  0.634  0.428    6.6
# ..       ...       ...     ...    ...    ...    ...    ...    ...    ...
# 132      146     0.391     373  0.140  0.263  0.250  0.330  0.279   -0.8
# 125      173     0.416     416  0.170  0.291  0.243  0.400  0.310   -0.5
# 115      143     0.432     331  0.191  0.300  0.242  0.395  0.314   -0.8
# 129      125     0.334     374  0.177  0.280  0.222  0.333  0.271   -0.7
# 116      119     0.317     375  0.151  0.236  0.245  0.344  0.305   -0.9
#
# [133 rows x 320 columns]
